# %% [markdown]
# <a href="https://colab.research.google.com/github/lutfiahintan/TubesCloudComputing/blob/main/TubesCC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Connect to Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# import library yang digunakan

# %%
import zipfile
import os
import glob 
import warnings

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dense, Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.optimizers import Adam
import tensorflow as tf

# %%
from keras.preprocessing import image
from google.colab import files
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %% [markdown]
# Masuk Ke dalam direktori Dataset

# %%
cd /content/drive/MyDrive/Colab Notebooks/TubesCC
# Out:
# /content/drive/MyDrive/Colab Notebooks/TubesCC

# %% [markdown]
# Cek isi didalam folder TubesCC

# %%
ls
# Out:
# dataset_wajah.zip

# %% [markdown]
# Melakukan Ekstrak File Dataset

# %%
ekstrak_zip = 'dataset_wajah.zip'
out_zip = zipfile.ZipFile(ekstrak_zip, 'r')
out_zip.extractall('/dataset_wajah')
out_zip.close()

# %% [markdown]
# Mengatur Lokasi Direktori Dataset

# %%
dir_dataset = "/dataset_wajah/wajah"
dir_wajahberkomedo = os.path.join("/dataset_wajah/wajah/wajahberkomedo")
dir_wajahnormal = os.path.join("/dataset_wajah/wajah/wajahnormal")

# %%
total_image = len(list(glob.iglob("/dataset_wajah/wajah/*/*.*", recursive=True)))
total_wajahberkomedo = len(os.listdir(dir_wajahberkomedo))
total_wajahnormal = len(os.listdir(dir_wajahnormal))

# %% [markdown]
# Menghitung Jumlah File Dataset

# %%
print("Total Data Wajab Berkomedo      : ",total_wajahberkomedo)
print("Total Data Wajah Normal       : ",total_wajahnormal)
print("Total Data Image JPEG     : ",total_image)
# Out:
# Total Data Wajab Berkomedo      :  162
# Total Data Wajah Normal       :  600
# Total Data Image JPEG     :  762

# %% [markdown]
# Pengaturan Image Data Generator Tensorflow Untuk Pengolahan Gambar

# %%
val_size = 0.2
Train_datagen = ImageDataGenerator(
    rotation_range = 45,
    brightness_range = [0.2,1.0],
    shear_range = 0.3,
    zoom_range = 0.3,
    horizontal_flip = True,
    fill_mode = "nearest",
    rescale = 1./255,
    validation_split = val_size
)
Validation_datagen = ImageDataGenerator(
    rotation_range = 45,
    brightness_range = [0.2,1.0],
    shear_range = 0.3,
    zoom_range = 0.3,
    horizontal_flip = True,
    fill_mode = "nearest",
    rescale = 1./255,
    validation_split = val_size
)

# %% [markdown]
# Mengatur Dimensi Gambar

# %%
img_width = 200
img_height = 200

# %% [markdown]
# Melakukan Split Dataset Train dan Validation Dengan Ukuran Validasi 20%

# %%
Train_generator = Train_datagen.flow_from_directory(
    dir_dataset,
    target_size = (img_width,img_height),
    color_mode = "rgb",
    class_mode = "categorical",
    batch_size = 20,
    shuffle = True,
    subset = "training"
)
Validation_generator = Validation_datagen.flow_from_directory(
    dir_dataset,
    target_size = (img_width,img_height),
    color_mode = "rgb",
    class_mode = "categorical",
    batch_size = 20,
    shuffle = False,
    subset = "validation"
)
# Out:
# Found 610 images belonging to 2 classes.
# Found 152 images belonging to 2 classes.

# %% [markdown]
# Mengatur Model Sequential Yang Digunakan

# %%
Model = Sequential(
    [Conv2D(16, (3,3), strides = (1,1), activation = 'relu' , input_shape = (img_width,img_height,3)),
     MaxPooling2D(pool_size = (2,2), padding = 'valid'),
     Conv2D(32, (3,3), strides = (1,1), activation = 'relu' ),
     MaxPooling2D(pool_size = (2,2), padding = 'valid'),
     Conv2D(64, (3,3), strides = (1,1), activation = 'relu' ),
     MaxPooling2D(pool_size = (2,2), padding = 'valid'),
     Flatten(),
     Dropout(0.3),
     Dense(128, activation = 'relu'),
     Dense(2, activation='softmax')
    ]
)

# %%
Model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 198, 198, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 99, 99, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 97, 97, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 48, 48, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 46, 46, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 23, 23, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 33856)             0
#
#  dropout (Dropout)           (None, 33856)             0
#
#  dense (Dense)               (None, 128)               4333696
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 4,357,538
# Trainable params: 4,357,538
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Mengatur Optimizer Yang Digunakan

# %%
Adam(learning_rate=0.00146, name='Adam')
Model.compile(optimizer = 'Adam',loss = 'categorical_crossentropy',metrics = ['accuracy'])

# %% [markdown]
# Mengatur Learning Rate Schedule dan Callbacks Yang Digunakan

# %%
def scheduler(epoch, lr):
  if epoch < 5:
    return lr
  else:
    return lr * tf.math.exp(-0.1)
lr_schedule = tf.keras.callbacks.LearningRateScheduler(scheduler, verbose=1)
tb_callback = tf.keras.callbacks.TensorBoard(
    log_dir='logs', histogram_freq=0, write_graph=True, write_images=False,
    update_freq='epoch', embeddings_freq=0,
    embeddings_metadata=None
)

# %% [markdown]
# Melakukan Training Pada Dataset

# %%
batch_size = 20
with tf.device("/device:GPU:0"):
  history = Model.fit(Train_generator, 
                    epochs =  30, 
                    steps_per_epoch = 610//batch_size, 
                    validation_data = Validation_generator, 
                    verbose = 1, 
                    validation_steps = 152//batch_size,
                    callbacks =[lr_schedule, tb_callback])
# Out:
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 1/30
# 30/30 [==============================] - 34s 1s/step - loss: 0.4746 - accuracy: 0.7847 - val_loss: 0.2989 - val_accuracy: 0.8714 - lr: 0.0010
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 2/30
# 30/30 [==============================] - 34s 1s/step - loss: 0.2393 - accuracy: 0.8559 - val_loss: 0.2024 - val_accuracy: 0.9214 - lr: 0.0010
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 3/30
# 30/30 [==============================] - 34s 1s/step - loss: 0.1547 - accuracy: 0.9424 - val_loss: 0.1020 - val_accuracy: 0.9643 - lr: 0.0010
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 4/30
# 30/30 [==============================] - 33s 1s/step - loss: 0.0967 - accuracy: 0.9780 - val_loss: 0.1546 - val_accuracy: 0.9214 - lr: 0.0010
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 5/30
# 30/30 [==============================] - 34s 1s/step - loss: 0.1125 - accuracy: 0.9627 - val_loss: 0.2150 - val_accuracy: 0.9357 - lr: 0.0010
#
# Epoch 00006: LearningRateScheduler setting learning rate to tf.Tensor(0.00090483745, shape=(), dtype=float32).
# Epoch 6/30
# 30/30 [==============================] - 33s 1s/step - loss: 0.0628 - accuracy: 0.9763 - val_loss: 0.0745 - val_accuracy: 0.9643 - lr: 9.0484e-04
#
# Epoch 00007: LearningRateScheduler setting learning rate to tf.Tensor(0.0008187308, shape=(), dtype=float32).
# Epoch 7/30
# 30/30 [==============================] - 34s 1s/step - loss: 0.0503 - accuracy: 0.9831 - val_loss: 0.0923 - val_accuracy: 0.9714 - lr: 8.1873e-04
#
# Epoch 00008: LearningRateScheduler setting learning rate to tf.Tensor(0.0007408183, shape=(), dtype=float32).
# Epoch 8/30
# 30/30 [==============================] - 34s 1s/step - loss: 0.0558 - accuracy: 0.9763 - val_loss: 0.1542 - val_accuracy: 0.9571 - lr: 7.4082e-04
#
# Epoch 00009: LearningRateScheduler setting learning rate to tf.Tensor(0.0006703201, shape=(), dtype=float32).
# Epoch 9/30
# 30/30 [==============================] - 34s 1s/step - loss: 0.0511 - accuracy: 0.9831 - val_loss: 0.1500 - val_accuracy: 0.9500 - lr: 6.7032e-04
#
# Epoch 00010: LearningRateScheduler setting learning rate to tf.Tensor(0.00060653075, shape=(), dtype=float32).
# Epoch 10/30
# 30/30 [==============================] - 34s 1s/step - loss: 0.0797 - accuracy: 0.9746 - val_loss: 0.0515 - val_accuracy: 0.9786 - lr: 6.0653e-04
#
# Epoch 00011: LearningRateScheduler setting learning rate to tf.Tensor(0.00054881175, shape=(), dtype=float32).
# Epoch 11/30
# 30/30 [==============================] - 34s 1s/step - loss: 0.0514 - accuracy: 0.9817 - val_loss: 0.0497 - val_accuracy: 0.9786 - lr: 5.4881e-04
#
# Epoch 00012: LearningRateScheduler setting learning rate to tf.Tensor(0.0004965854, shape=(), dtype=float32).
# Epoch 12/30
# 30/30 [==============================] - 34s 1s/step - loss: 0.0278 - accuracy: 0.9915 - val_loss: 0.0498 - val_accuracy: 0.9786 - lr: 4.9659e-04
#
# Epoch 00013: LearningRateScheduler setting learning rate to tf.Tensor(0.00044932903, shape=(), dtype=float32).
# Epoch 13/30
# 30/30 [==============================] - 34s 1s/step - loss: 0.0447 - accuracy: 0.9831 - val_loss: 0.0491 - val_accuracy: 0.9786 - lr: 4.4933e-04
#
# Epoch 00014: LearningRateScheduler setting learning rate to tf.Tensor(0.0004065697, shape=(), dtype=float32).
# Epoch 14/30
# 30/30 [==============================] - 33s 1s/step - loss: 0.0360 - accuracy: 0.9898 - val_loss: 0.1324 - val_accuracy: 0.9571 - lr: 4.0657e-04
#
# Epoch 00015: LearningRateScheduler setting learning rate to tf.Tensor(0.0003678795, shape=(), dtype=float32).
# Epoch 15/30
# 30/30 [==============================] - 34s 1s/step - loss: 0.0286 - accuracy: 0.9864 - val_loss: 0.0599 - val_accuracy: 0.9857 - lr: 3.6788e-04
#
# Epoch 00016: LearningRateScheduler setting learning rate to tf.Tensor(0.00033287113, shape=(), dtype=float32).
# Epoch 16/30
# 30/30 [==============================] - 34s 1s/step - loss: 0.0275 - accuracy: 0.9898 - val_loss: 0.1431 - val_accuracy: 0.9571 - lr: 3.3287e-04
#
# Epoch 00017: LearningRateScheduler setting learning rate to tf.Tensor(0.00030119426, shape=(), dtype=float32).
# Epoch 17/30
# 30/30 [==============================] - 34s 1s/step - loss: 0.0273 - accuracy: 0.9898 - val_loss: 0.3244 - val_accuracy: 0.9429 - lr: 3.0119e-04
#
# Epoch 00018: LearningRateScheduler setting learning rate to tf.Tensor(0.00027253185, shape=(), dtype=float32).
# Epoch 18/30
# 30/30 [==============================] - 34s 1s/step - loss: 0.0220 - accuracy: 0.9915 - val_loss: 0.0729 - val_accuracy: 0.9786 - lr: 2.7253e-04
#
# Epoch 00019: LearningRateScheduler setting learning rate to tf.Tensor(0.00024659702, shape=(), dtype=float32).
# Epoch 19/30
# 30/30 [==============================] - 34s 1s/step - loss: 0.0328 - accuracy: 0.9864 - val_loss: 0.0889 - val_accuracy: 0.9714 - lr: 2.4660e-04
#
# Epoch 00020: LearningRateScheduler setting learning rate to tf.Tensor(0.0002231302, shape=(), dtype=float32).
# Epoch 20/30
# 30/30 [==============================] - 34s 1s/step - loss: 0.0305 - accuracy: 0.9932 - val_loss: 0.1177 - val_accuracy: 0.9857 - lr: 2.2313e-04
#
# Epoch 00021: LearningRateScheduler setting learning rate to tf.Tensor(0.00020189656, shape=(), dtype=float32).
# Epoch 21/30
# 30/30 [==============================] - 34s 1s/step - loss: 0.0180 - accuracy: 0.9932 - val_loss: 0.0968 - val_accuracy: 0.9714 - lr: 2.0190e-04
#
# Epoch 00022: LearningRateScheduler setting learning rate to tf.Tensor(0.00018268357, shape=(), dtype=float32).
# Epoch 22/30
# 30/30 [==============================] - 34s 1s/step - loss: 0.0343 - accuracy: 0.9915 - val_loss: 0.0356 - val_accuracy: 0.9857 - lr: 1.8268e-04
#
# Epoch 00023: LearningRateScheduler setting learning rate to tf.Tensor(0.00016529893, shape=(), dtype=float32).
# Epoch 23/30
# 30/30 [==============================] - 33s 1s/step - loss: 0.0354 - accuracy: 0.9864 - val_loss: 0.0379 - val_accuracy: 0.9857 - lr: 1.6530e-04
#
# Epoch 00024: LearningRateScheduler setting learning rate to tf.Tensor(0.00014956866, shape=(), dtype=float32).
# Epoch 24/30
# 30/30 [==============================] - 33s 1s/step - loss: 0.0149 - accuracy: 0.9983 - val_loss: 0.0860 - val_accuracy: 0.9786 - lr: 1.4957e-04
#
# Epoch 00025: LearningRateScheduler setting learning rate to tf.Tensor(0.00013533531, shape=(), dtype=float32).
# Epoch 25/30
# 30/30 [==============================] - 34s 1s/step - loss: 0.0105 - accuracy: 0.9983 - val_loss: 0.0627 - val_accuracy: 0.9714 - lr: 1.3534e-04
#
# Epoch 00026: LearningRateScheduler setting learning rate to tf.Tensor(0.00012245646, shape=(), dtype=float32).
# Epoch 26/30
# 30/30 [==============================] - 33s 1s/step - loss: 0.0282 - accuracy: 0.9898 - val_loss: 0.0364 - val_accuracy: 0.9857 - lr: 1.2246e-04
#
# Epoch 00027: LearningRateScheduler setting learning rate to tf.Tensor(0.000110803194, shape=(), dtype=float32).
# Epoch 27/30
# 30/30 [==============================] - 33s 1s/step - loss: 0.0150 - accuracy: 0.9949 - val_loss: 0.0826 - val_accuracy: 0.9714 - lr: 1.1080e-04
#
# Epoch 00028: LearningRateScheduler setting learning rate to tf.Tensor(0.000100258876, shape=(), dtype=float32).
# Epoch 28/30
# 30/30 [==============================] - 34s 1s/step - loss: 0.0203 - accuracy: 0.9983 - val_loss: 0.0680 - val_accuracy: 0.9714 - lr: 1.0026e-04
#
# Epoch 00029: LearningRateScheduler setting learning rate to tf.Tensor(9.0717986e-05, shape=(), dtype=float32).
# Epoch 29/30
# 30/30 [==============================] - 33s 1s/step - loss: 0.0207 - accuracy: 0.9915 - val_loss: 0.1174 - val_accuracy: 0.9786 - lr: 9.0718e-05
#
# Epoch 00030: LearningRateScheduler setting learning rate to tf.Tensor(8.2085025e-05, shape=(), dtype=float32).
# Epoch 30/30
# 30/30 [==============================] - 33s 1s/step - loss: 0.0147 - accuracy: 0.9966 - val_loss: 0.0833 - val_accuracy: 0.9857 - lr: 8.2085e-05

# %% [markdown]
# Membuat Plot Accuracy dan Loss Pada Hasil Training Dataset

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs = range(len(acc))
plt.plot(epochs, acc, 'b', label='Train accuracy')
plt.plot(epochs, val_acc, 'y', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)
plt.figure()
plt.show()

plt.plot(epochs, loss, 'b', label='Train loss')
plt.plot(epochs, val_loss, 'y', label='Validation loss')
plt.title('Training and validation loss')
plt.legend(loc=0)
plt.figure()
plt.show()

# %% [markdown]
# Melakukan Upload File Gambar Untuk Dilakukan Prediksi

# %%
uploaded = files.upload()

for file_upload in uploaded.keys():
  path = file_upload
  img = image.load_img(path, target_size=(200,200))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)

  images = np.vstack([x])
  classes = Model.predict(images, batch_size=20)
  
  print("\n")
  if classes[0][0] == 1:
    print('\t Wajah Berkomedo')
  elif classes[0][1] == 1:
    print('\t Wajah Normal')
# Out:
#      <input type="file" id="files-9cb5e663-69d6-4be9-a785-f587d97b8417" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9cb5e663-69d6-4be9-a785-f587d97b8417">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 28.jpg to 28.jpg
#
#
# 	 Wajah Berkomedo
